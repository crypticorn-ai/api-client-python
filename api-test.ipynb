# %%
# %pip install crypticorn

# %% [markdown]
# Public usage

# %%
from crypticorn import Crypticorn

client = Crypticorn(api_key="sk-proj-1234567890")

# public endpoints
client.create_model()

# %% [markdown]
# Private usage

# %%
from client import ApiClient

client = ApiClient(api_key="REDACTED")

# private endpoints
client.hive.create_account()
